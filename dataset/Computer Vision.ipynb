# %%
import os
from copy import deepcopy
from dataclasses import dataclass
from typing import Dict, List
from datasets import load_dataset, set_caching_enabled
import numpy as np
from PIL import Image
import torch
from transformers import (
    # Preprocessing
    AutoTokenizer, AutoFeatureExtractor,
    # Misc
    logging
)
import matplotlib.pyplot as plt

########
# copied this from kaggle dataset because we are not sure how GPU setup works 
set_caching_enabled(True) # cache the dataset
logging.set_verbosity_error()
torch.cuda.empty_cache() # empty cache before starting 
device = torch.device("cuda") # set gpu 
print(device)
########
# load in dataset 
dataset = load_dataset(
    "csv", 
    data_files={
        "train": os.path.join("dataset","data_train.csv"),
        "test": os.path.join("dataset", "data_eval.csv")
    }
)
# load in list of all possible answers 
with open(os.path.join("dataset", "answer_space.txt")) as f:
    answer_space = f.read().splitlines()

# map answers to their indices in the answer space list 
dataset = dataset.map(
    lambda examples: {
        'label': [
            #  Select the 1st answer if multiple answers are provided
            answer_space.index(ans.replace(" ", "").split(",")[0]) 
            for ans in examples['answer']
        ]
    },
    batched=True
)

def showImage(id):
    '''
    Function used for displaying the image during inference.
    '''
    image = Image.open(os.path.join("dataset", "images", 
    dataset['test'][id]['image_id']+".png"))
    plt.imshow(image)
    plt.show()
    print("Question:\t", dataset['test'][id]['question'])
    print("Answer:\t\t", dataset['test'][id]['answer'])


@dataclass
class MultimodalCollator:
    '''
    Custom class for collating data.  
    '''
    tokenizer: AutoTokenizer
    preprocessor: AutoFeatureExtractor
    is_personal = False # flag for whether the image should come from our 
                        # personal image dataset or not 

    def tokenize_text(self, texts: List[str]):
        '''
        Defines tokenizer for RoBERTa; returns BPE tokens. 
        '''
        encoded_text = self.tokenizer(
            text=texts,
            padding='longest',
            max_length=24,
            truncation=True,
            return_tensors='pt',
            return_token_type_ids=True,
            return_attention_mask=True,
        )
        return {
            "text_features": encoded_text 
        }

    def preprocess_images(self, images: List[str]):
        '''
        Converts image to RGB and feed them to ViT feature extractor;
        then returns the extracted/normalized pixel values. 
        '''
        processed_images = self.preprocessor(
            images= [
            Image.open(
            os.path.join("personal", image_id+".png")).convert('RGB') 
            for image_id in images] if self.is_personal
            else [
            Image.open(
            os.path.join("dataset", "images", image_id + ".png")).convert('RGB') 
            for image_id in images],
            return_tensors="pt",
        )
        return {
            "img_features": processed_images 
        }
            
    def __call__(self, raw_batch_dict):
        '''
        Returns the data in our desired format. 
        ''' 
        return {
            **self.tokenize_text(
                raw_batch_dict['question']
                if isinstance(raw_batch_dict, dict) else
                [i['question'] for i in raw_batch_dict]
            ),
            **self.preprocess_images(
                raw_batch_dict['image_id']
                if isinstance(raw_batch_dict, dict) else
                ([i['image_id'] for i in raw_batch_dict])
            ),
            'labels': torch.tensor(
                raw_batch_dict['label']
                if isinstance(raw_batch_dict, dict) else
                [i['label'] for i in raw_batch_dict],
                dtype=torch.int64
            ),
        }
# Out:
# cuda
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 26
#      23 print(device)
#      24 ########
#      25 # load in dataset
# ---> 26 dataset = load_dataset(
#      27     "csv",
#      28     data_files={
#      29         "train": os.path.join("dataset","data_train.csv"),
#      30         "test": os.path.join("dataset", "data_eval.csv")
#      31     }
#      32 )
#      33 # load in list of all possible answers
#      34 with open(os.path.join("dataset", "answer_space.txt")) as f:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\load.py:2592, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2587 verification_mode = VerificationMode(
#    2588     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2589 )
#    2591 # Create a dataset builder
# -> 2592 builder_instance = load_dataset_builder(
#    2593     path=path,
#    2594     name=name,
#    2595     data_dir=data_dir,
#    2596     data_files=data_files,
#    2597     cache_dir=cache_dir,
#    2598     features=features,
#    2599     download_config=download_config,
#    2600     download_mode=download_mode,
#    2601     revision=revision,
#    2602     token=token,
#    2603     storage_options=storage_options,
#    2604     trust_remote_code=trust_remote_code,
#    2605     _require_default_config_name=name is None,
#    2606     **config_kwargs,
#    2607 )
#    2609 # Return iterable dataset in case of streaming
#    2610 if streaming:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\load.py:2264, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, use_auth_token, storage_options, trust_remote_code, _require_default_config_name, **config_kwargs)
#    2262     download_config = download_config.copy() if download_config else DownloadConfig()
#    2263     download_config.storage_options.update(storage_options)
# -> 2264 dataset_module = dataset_module_factory(
#    2265     path,
#    2266     revision=revision,
#    2267     download_config=download_config,
#    2268     download_mode=download_mode,
#    2269     data_dir=data_dir,
#    2270     data_files=data_files,
#    2271     cache_dir=cache_dir,
#    2272     trust_remote_code=trust_remote_code,
#    2273     _require_default_config_name=_require_default_config_name,
#    2274     _require_custom_configs=bool(config_kwargs),
#    2275 )
#    2276 # Get dataset builder class from the processing script
#    2277 builder_kwargs = dataset_module.builder_kwargs
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\load.py:1804, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1781 # We have several ways to get a dataset builder:
#    1782 #
#    1783 # - if path is the name of a packaged dataset module
#    (...)
#    1795
#    1796 # Try packaged
#    1797 if path in _PACKAGED_DATASETS_MODULES:
#    1798     return PackagedDatasetModuleFactory(
#    1799         path,
#    1800         data_dir=data_dir,
#    1801         data_files=data_files,
#    1802         download_config=download_config,
#    1803         download_mode=download_mode,
# -> 1804     ).get_module()
#    1805 # Try locally
#    1806 elif path.endswith(filename):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\load.py:1141, in PackagedDatasetModuleFactory.get_module(self)
#    1135 base_path = Path(self.data_dir or "").expanduser().resolve().as_posix()
#    1136 patterns = (
#    1137     sanitize_patterns(self.data_files)
#    1138     if self.data_files is not None
#    1139     else get_data_patterns(base_path, download_config=self.download_config)
#    1140 )
# -> 1141 data_files = DataFilesDict.from_patterns(
#    1142     patterns,
#    1143     download_config=self.download_config,
#    1144     base_path=base_path,
#    1145 )
#    1146 supports_metadata = self.name in _MODULE_SUPPORTS_METADATA
#    1147 if self.data_files is None and supports_metadata and patterns != DEFAULT_PATTERNS_ALL:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\data_files.py:715, in DataFilesDict.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     712 out = cls()
#     713 for key, patterns_for_key in patterns.items():
#     714     out[key] = (
# --> 715         DataFilesList.from_patterns(
#     716             patterns_for_key,
#     717             base_path=base_path,
#     718             allowed_extensions=allowed_extensions,
#     719             download_config=download_config,
#     720         )
#     721         if not isinstance(patterns_for_key, DataFilesList)
#     722         else patterns_for_key
#     723     )
#     724 return out
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\data_files.py:620, in DataFilesList.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     617 for pattern in patterns:
#     618     try:
#     619         data_files.extend(
# --> 620             resolve_pattern(
#     621                 pattern,
#     622                 base_path=base_path,
#     623                 allowed_extensions=allowed_extensions,
#     624                 download_config=download_config,
#     625             )
#     626         )
#     627     except FileNotFoundError:
#     628         if not has_magic(pattern):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\data_files.py:407, in resolve_pattern(pattern, base_path, allowed_extensions, download_config)
#     405     if allowed_extensions is not None:
#     406         error_msg += f" with any supported extension {list(allowed_extensions)}"
# --> 407     raise FileNotFoundError(error_msg)
#     408 return out
#
# FileNotFoundError: Unable to find 'C:/Users/M-HADI/Documents/Computer Vision\dataset\data_train.csv'

# %%
pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in c:\users\m-hadi\appdata\local\programs\python\python311\lib\site-packages (0.23.2)
# Requirement already satisfied: filelock in c:\users\m-hadi\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\m-hadi\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub) (2024.2.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\m-hadi\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\m-hadi\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in c:\users\m-hadi\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\m-hadi\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub) (4.66.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\m-hadi\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub) (4.9.0)
# Requirement already satisfied: colorama in c:\users\m-hadi\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\m-hadi\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\m-hadi\appdata\roaming\python\python311\site-packages (from requests->huggingface_hub) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\m-hadi\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\m-hadi\appdata\roaming\python\python311\site-packages (from requests->huggingface_hub) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.
